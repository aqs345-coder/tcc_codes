# %% [markdown]
# # Este repositório consiste em aplicações de filtro de <span style="color:red">Kalman</span> para ciência de dados

# %% [markdown]
# ## Na pasta nomeada "examples" se encontram as implementações dos exemplos disponíveis na [página web](https://kalmanfilter.net/PT/default_pt.aspx)
